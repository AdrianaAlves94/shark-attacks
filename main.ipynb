# %%
# Import the specific functions from your other file
from data_digger import loadFile, conclude

def main():
    processed_df = loadFile('https://www.sharkattackfile.net/spreadsheets/GSAF5.xls')
    conclude(processed_df)

if __name__ == "__main__":
    main()
