# %%
from data_digger import loadFile, run_summary

def main():
    processed_df = loadFile('https://www.sharkattackfile.net/spreadsheets/GSAF5.xls')
    run_summary(processed_df)

if __name__ == "__main__":
    main()
