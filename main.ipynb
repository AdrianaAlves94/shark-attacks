# %%
from data_digger import loadFileAndClean, run_summary

def main():
    processed_df = loadFileAndClean('https://www.sharkattackfile.net/spreadsheets/GSAF5.xls')
    display(processed_df)
    run_summary(processed_df)

if __name__ == "__main__":
    main()
# Out:
# Connecting to database and fetching latest records...
#
# Wohoo, Data is fetched successfully !!
#                Date    Year        Type       Country  \
# 18    25th December  2025.0  Unprovoked    MOZAMBIQUE
# 19    21st December  2025.0  Unprovoked     AUSTRALIA
# 20    21st December  2025.0  Unprovoked           USA
# 21    12th December  2025.0  Unprovoked           USA
# 22     9th December  2025.0    Provoked           USA
# ...             ...     ...         ...           ...
# 6327    14-Jul-1900  1900.0     Invalid           USA
# 6328  Late Jul-1900  1900.0    Provoked           USA
# 6329    28-Jan-1900  1900.0  Unprovoked     AUSTRALIA
# 6330    Early 1900s  1900.0  Unprovoked           USA
# 6331       Ca. 1900  1900.0  Unprovoked  SOUTH AFRICA
#
#                              State  \
# 18                Inhambe Province
# 19               Western Australia
# 20                      California
# 21        Sonoma County California
# ...
